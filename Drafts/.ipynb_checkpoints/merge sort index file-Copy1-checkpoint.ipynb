# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime as dtb
import os
from glob import glob
import datetime
import seaborn as sns

data = [pd.read_csv('C:/Users/RAPP/Documents/Capstone/HOUREMIS3_file_1-29.dat', dtype = 'str', header = 0, delim_whitespace = True)]
#data = [pd.read_csv('C:/Users/RAPP/Documents/Capstone/HOUREMIS3_file_1-29.dat', header = 0, delimiter = " ")]

df = pd.concat(data)
print(df.describe())
NE_df = df.copy()
NW_df = df.copy()
NE_df['SRC'] = ['NE_'+ str(col) for col in NE_df['SRC'] ]
NW_df['SRC'] = ['NW_'+ str(col) for col in NW_df['SRC'] ]
#print(NE_df)

NENW_df = pd.concat([NE_df, NW_df]).sort_index()


print(NENW_df)
# Out:
#             SO      PATH    YEAR      MM      DD      HH     SRC    RATE  \
# count   350592    350592  350592  350592  350592  350592  350592  350592
# unique       1         1       5      12      31      24       8       3
# top         SO  HOUREMIS    2016      03      03      03   FRAC7   0.000
# freq    350592    350592   70272   29760   11520   14608   43824  327552
#
#           TEMP     VEL
# count   350592  350592
# unique       3       3
# top      0.000   0.000
# freq    327552  327552
#         SO      PATH  YEAR  MM  DD  HH       SRC   RATE   TEMP    VEL
# 0       SO  HOUREMIS  2013  01  01  01  NE_FRAC1  0.000  0.000  0.000
# 0       SO  HOUREMIS  2013  01  01  01  NW_FRAC1  0.000  0.000  0.000
# 1       SO  HOUREMIS  2013  01  01  01  NW_FRAC2  0.000  0.000  0.000
# 1       SO  HOUREMIS  2013  01  01  01  NE_FRAC2  0.000  0.000  0.000
# 2       SO  HOUREMIS  2013  01  01  01  NE_FRAC3  0.000  0.000  0.000
# ...
