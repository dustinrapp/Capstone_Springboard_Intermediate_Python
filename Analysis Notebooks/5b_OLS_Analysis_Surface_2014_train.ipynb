# %% [markdown]
# ## Data Prep

# %% [markdown]
# **Import necessary modules and the ASOS/SNOTEL dataframes**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime as dtb
import os
from glob import glob
import datetime as dt
import seaborn as sns

# %%
data = [pd.read_csv('asos_snotel_UA_12hr_df.dat', parse_dates = True, index_col = 'Date_Time')]
asos_snotel_UA_df = pd.concat(data)
#asos_snotel_UA_df['LXV_WindSpeed_m/s']

#asos_snotel_UA_df.rename(columns={'LXV_WindSpeed_m/s': 'LXV_WindSpeed_mps'}, inplace=True)

asos_snotel_UA_df.astype('float16')
pd.set_option('display.expand_frame_repr', True)


print(asos_snotel_UA_df.keys())




#delete empty columns as they mess up loops
#del asos_snotel_UA_df['CMtn_6hr_Precipitation_mm']            #empty column
# Out:
# Index(['CMtnSNTL_Temp_degC', 'CMtnSNTL_SnowDepth_in', 'CMtn_Temperature_degC',
#        'CMtn_Dewpoint_degC', 'CMtn_WindDirection_deg', 'CMtn_WindSpeed_mps',
#        'CMtn_CloudCover_oktas', 'CMtn_1hr_Precipitation_mm',
#        'LXV_Temperature_degC', 'LXV_Dewpoint_degC',
#        ...
#        'KGJT_d300_200_height_m', 'KGJT_d300_200_tmpc', 'KGJT_d300_200_dwpc',
#        'KGJT_d300_200_drct', 'KGJT_d300_200_speed_kts',
#        'KGJT_d250_200_height_m', 'KGJT_d250_200_tmpc', 'KGJT_d250_200_dwpc',
#        'KGJT_d250_200_drct', 'KGJT_d250_200_speed_kts'],
#       dtype='object', length=163)

# %% [markdown]
# It is important to keep in mind that 'CMtnSNTL_12hr_SNWD_in contains snow depth info taken at the start of the respective 12hr period timestamp.  The snowfall calculated also gives the snowfall that fell in the 12hrs after the timestamp.  The OLS model will utilize hourly meteorological measurements at exactly 00:00 and 12:00 hours to predict the amount of snow which will fall in the next 12 hour period.  For example, the 00:00 meteorological measurements will be used to predict the snow which fell between 00:00 and 12:00.

# %%
all_yrs = (asos_snotel_UA_df.index >= '01-01-2006') & (asos_snotel_UA_df.index < '01-01-2018')
train_yrs = ((asos_snotel_UA_df.index >= '01-01-2006') & (asos_snotel_UA_df.index < '01-01-2013')) | ((asos_snotel_UA_df.index >= '01-01-2015') & (asos_snotel_UA_df.index < '01-01-2018'))
test_yrs = (asos_snotel_UA_df.index >= '01-01-2013') & (asos_snotel_UA_df.index <= '01-01-2015')

test = (asos_snotel_UA_df.index >= '01-01-2006') & (asos_snotel_UA_df.index < '01-02-2006')
print(asos_snotel_UA_df['KGJT_d300_200_height_m'][test])

print(asos_snotel_UA_df[all_yrs]['CMtnSNTL_Temp_degC'].describe())
print(asos_snotel_UA_df[test_yrs]['CMtnSNTL_Temp_degC'].describe())
print(asos_snotel_UA_df[train_yrs]['CMtnSNTL_Temp_degC'].describe())
# Out:
# Date_Time
# 2006-01-01 00:00:00+00:00   -2630.0
# 2006-01-01 12:00:00+00:00   -2700.0
# Name: KGJT_d300_200_height_m, dtype: float64
# count    8710.000000
# mean       -0.001883
# std         8.559429
# min       -30.600000
# 25%        -6.270000
# 50%         0.000000
# 75%         7.300000
# max        19.100000
# Name: CMtnSNTL_Temp_degC, dtype: float64
# count    1461.000000
# mean       -0.473443
# std         8.741779
# min       -27.000000
# 25%        -6.800000
# 50%        -0.800000
# 75%         7.300000
# max        17.900000
# Name: CMtnSNTL_Temp_degC, dtype: float64
# count    7250.000000
# mean        0.091476
# std         8.520274
# min       -30.600000
# 25%        -6.100000
# 50%         0.200000
# 75%         7.300000
# max        19.100000
# Name: CMtnSNTL_Temp_degC, dtype: float64

# %% [markdown]
# ***
# # OLS Analysis of meteorological variables and snowfall (Training Dataset: 2008-2017 only)

# %% [markdown]
# **We will first utilize just the Copper Mountain surface level variables and run the model explicitly to generate statistics.  This will give snowfall predictive capability of individual meteorological variables (Dewpoint, SNOTEL Temperature, Temperature, Wind Speed, Cloud Cover, Wind Direction, 6hr Pressure change, and Pressure) using an OLS model and the 2008-2017 training dataset. The resulting values will also be used to verify some code which performs same analysis, but with a loop.  This code will then be fed all upper air and surface level variables to determine best combination of variables in the OLS model.**

# %%
#Import statsmodel

import statsmodels.api as sm
#import statsmodel
from statsmodels.formula.api import ols

# %% [markdown]
# ### Single Surface Variable OLS (no filtering)

# %%
OLS_CMtn_Dewpoint = ols('CMtnSNTL_Upcoming12hrSNOWFALL_gte3_in ~ CMtn_Dewpoint_degC',asos_snotel_UA_df[train_yrs]).fit()
OLS_CMtnSNTL_Temp = ols('CMtnSNTL_Upcoming12hrSNOWFALL_gte3_in ~ CMtnSNTL_Temp_degC',asos_snotel_UA_df[train_yrs]).fit()
OLS_CMtn_Temperature = ols('CMtnSNTL_Upcoming12hrSNOWFALL_gte3_in ~ CMtn_Temperature_degC',asos_snotel_UA_df[train_yrs]).fit()
OLS_CMtn_WindSpeed = ols('CMtnSNTL_Upcoming12hrSNOWFALL_gte3_in ~ CMtn_WindSpeed_mps',asos_snotel_UA_df[train_yrs]).fit()
OLS_CMtn_CloudCover = ols('CMtnSNTL_Upcoming12hrSNOWFALL_gte3_in ~ CMtn_CloudCover_oktas', asos_snotel_UA_df[train_yrs]).fit()
OLS_CMtn_WindDirection = ols('CMtnSNTL_Upcoming12hrSNOWFALL_gte3_in ~ CMtn_WindDirection_deg', asos_snotel_UA_df[train_yrs]).fit()
OLS_LXV_12hr_delta_Pressure = ols('CMtnSNTL_Upcoming12hrSNOWFALL_gte3_in ~ LXV_12hr_delta_Pressure_hp', asos_snotel_UA_df[train_yrs]).fit()
OLS_LXV_Pressure = ols('CMtnSNTL_Upcoming12hrSNOWFALL_gte3_in ~ LXV_Pressure_hp', asos_snotel_UA_df[train_yrs]).fit()


print(OLS_CMtn_Dewpoint.summary())
print("\n ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++ \n")
print(OLS_CMtnSNTL_Temp.summary())
print("\n ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++ \n")
print(OLS_CMtn_Temperature.summary())
print("\n ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++ \n")
print(OLS_CMtn_WindSpeed.summary())
print("\n ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++ \n")
print(OLS_CMtn_CloudCover.summary())
print("\n ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++ \n")
print(OLS_CMtn_WindDirection.summary())
print("\n ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++ \n")
print(OLS_LXV_12hr_delta_Pressure.summary())
print("\n ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++ \n")
print(OLS_LXV_Pressure.summary())
print("\n ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++ \n")



#['CMtnSNTL_Temp_degC', 'CMtnSNTL_SnowDepth_in', 'CMtn_Temperature_degC',
#       'CMtn_Dewpoint_degC', 'CMtn_WindDirection_deg', 'CMtn_WindSpeed_mps',
#       'CMtn_CloudCover_oktas', 'CMtn_1hr_Precipitation_mm',
#       'LXV_Temperature_degC', 'LXV_Dewpoint_degC'


#print(a.rsquared)
#print(a.rsquared_adj)
#print(a.rsquared_adj)
#print(a.fvalue)
#print(a.f_pvalue)
#print(a.pvalues)
print(OLS_CMtn_Dewpoint.params)
#qq=sm.qqplot(a.resid, line='r')
# Out:
#                                       OLS Regression Results
# =================================================================================================
# Dep. Variable:     CMtnSNTL_Upcoming12hrSNOWFALL_gte3_in   R-squared:                       0.039
# Model:                                               OLS   Adj. R-squared:                  0.035
# Method:                                    Least Squares   F-statistic:                     9.205
# Date:                                   Fri, 17 May 2019   Prob (F-statistic):            0.00270
# Time:                                           23:02:12   Log-Likelihood:                -475.01
# No. Observations:                                    227   AIC:                             954.0
# Df Residuals:                                        225   BIC:                             960.9
# Df Model:                                              1
# Covariance Type:                               nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              5.3954      0.331     16.291      0.000       4.743       6.048
# CMtn_Dewpoint_degC     0.0918      0.030      3.034      0.003       0.032       0.151
# ==============================================================================
# Omnibus:                      123.782   Durbin-Watson:                   1.980
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              625.207
# Skew:                           2.205   Prob(JB):                    1.73e-136
# Kurtosis:                       9.830   Cond. No.                         27.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#  ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#                                       OLS Regression Results
# =================================================================================================
# Dep. Variable:     CMtnSNTL_Upcoming12hrSNOWFALL_gte3_in   R-squared:                       0.009
# Model:                                               OLS   Adj. R-squared:                  0.005
# Method:                                    Least Squares   F-statistic:                     2.410
# Date:                                   Fri, 17 May 2019   Prob (F-statistic):              0.122
# Time:                                           23:02:12   Log-Likelihood:                -573.09
# No. Observations:                                    269   AIC:                             1150.
# Df Residuals:                                        267   BIC:                             1157.
# Df Model:                                              1
# Covariance Type:                               nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              4.6778      0.170     27.550      0.000       4.343       5.012
# CMtnSNTL_Temp_degC     0.0506      0.033      1.552      0.122      -0.014       0.115
# ==============================================================================
# Omnibus:                      161.403   Durbin-Watson:                   1.949
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1062.095
# Skew:                           2.441   Prob(JB):                    2.34e-231
# Kurtosis:                      11.422   Cond. No.                         7.22
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#  ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#                                       OLS Regression Results
# =================================================================================================
# Dep. Variable:     CMtnSNTL_Upcoming12hrSNOWFALL_gte3_in   R-squared:                       0.010
# Model:                                               OLS   Adj. R-squared:                  0.005
# Method:                                    Least Squares   F-statistic:                     2.231
# Date:                                   Fri, 17 May 2019   Prob (F-statistic):              0.137
# Time:                                           23:02:12   Log-Likelihood:                -478.44
# No. Observations:                                    227   AIC:                             960.9
# Df Residuals:                                        225   BIC:                             967.7
# Df Model:                                              1
# Covariance Type:                               nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 4.6990      0.202     23.297      0.000       4.302       5.096
# CMtn_Temperature_degC     0.0464      0.031      1.494      0.137      -0.015       0.108
# ==============================================================================
# Omnibus:                      127.091   Durbin-Watson:                   2.022
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              660.571
# Skew:                           2.266   Prob(JB):                    3.62e-144
# Kurtosis:                      10.021   Cond. No.                         10.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#  ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#                                       OLS Regression Results
# =================================================================================================
# Dep. Variable:     CMtnSNTL_Upcoming12hrSNOWFALL_gte3_in   R-squared:                       0.003
# Model:                                               OLS   Adj. R-squared:                 -0.001
# Method:                                    Least Squares   F-statistic:                    0.7103
# Date:                                   Fri, 17 May 2019   Prob (F-statistic):              0.400
# Time:                                           23:02:12   Log-Likelihood:                -442.61
# No. Observations:                                    214   AIC:                             889.2
# Df Residuals:                                        212   BIC:                             896.0
# Df Model:                                              1
# Covariance Type:                               nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              4.1961      0.308     13.628      0.000       3.589       4.803
# CMtn_WindSpeed_mps     0.0313      0.037      0.843      0.400      -0.042       0.104
# ==============================================================================
# Omnibus:                      126.668   Durbin-Watson:                   1.978
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              763.921
# Skew:                           2.324   Prob(JB):                    1.31e-166
# Kurtosis:                      11.005   Cond. No.                         19.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#  ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#                                       OLS Regression Results
# =================================================================================================
# Dep. Variable:     CMtnSNTL_Upcoming12hrSNOWFALL_gte3_in   R-squared:                       0.020
# Model:                                               OLS   Adj. R-squared:                  0.013
# Method:                                    Least Squares   F-statistic:                     2.932
# Date:                                   Fri, 17 May 2019   Prob (F-statistic):             0.0890
# Time:                                           23:02:12   Log-Likelihood:                -290.33
# No. Observations:                                    145   AIC:                             584.7
# Df Residuals:                                        143   BIC:                             590.6
# Df Model:                                              1
# Covariance Type:                               nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 3.3283      0.644      5.166      0.000       2.055       4.602
# CMtn_CloudCover_oktas     0.1449      0.085      1.712      0.089      -0.022       0.312
# ==============================================================================
# Omnibus:                       63.324   Durbin-Watson:                   1.989
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              171.709
# Skew:                           1.797   Prob(JB):                     5.17e-38
# Kurtosis:                       6.937   Cond. No.                         33.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#  ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#                                       OLS Regression Results
# =================================================================================================
# Dep. Variable:     CMtnSNTL_Upcoming12hrSNOWFALL_gte3_in   R-squared:                       0.005
# Model:                                               OLS   Adj. R-squared:                  0.000
# Method:                                    Least Squares   F-statistic:                     1.044
# Date:                                   Fri, 17 May 2019   Prob (F-statistic):              0.308
# Time:                                           23:02:12   Log-Likelihood:                -442.44
# No. Observations:                                    214   AIC:                             888.9
# Df Residuals:                                        212   BIC:                             895.6
# Df Model:                                              1
# Covariance Type:                               nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                  3.9006      0.535      7.287      0.000       2.845       4.956
# CMtn_WindDirection_deg     0.0022      0.002      1.022      0.308      -0.002       0.007
# ==============================================================================
# Omnibus:                      125.382   Durbin-Watson:                   2.007
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              737.984
# Skew:                           2.305   Prob(JB):                    5.61e-161
# Kurtosis:                      10.843   Cond. No.                     1.00e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large,  1e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#  ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#                                       OLS Regression Results
# =================================================================================================
# Dep. Variable:     CMtnSNTL_Upcoming12hrSNOWFALL_gte3_in   R-squared:                       0.010
# Model:                                               OLS   Adj. R-squared:                  0.007
# Method:                                    Least Squares   F-statistic:                     2.764
# Date:                                   Fri, 17 May 2019   Prob (F-statistic):             0.0976
# Time:                                           23:02:12   Log-Likelihood:                -567.67
# No. Observations:                                    266   AIC:                             1139.
# Df Residuals:                                        264   BIC:                             1147.
# Df Model:                                              1
# Covariance Type:                               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      4.3894      0.144     30.563      0.000       4.107       4.672
# LXV_12hr_delta_Pressure_hp    -0.0384      0.023     -1.663      0.098      -0.084       0.007
# ==============================================================================
# Omnibus:                      162.417   Durbin-Watson:                   1.951
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1096.551
# Skew:                           2.480   Prob(JB):                    7.71e-239
# Kurtosis:                      11.622   Cond. No.                         7.13
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#  ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#                                       OLS Regression Results
# =================================================================================================
# Dep. Variable:     CMtnSNTL_Upcoming12hrSNOWFALL_gte3_in   R-squared:                       0.005
# Model:                                               OLS   Adj. R-squared:                  0.001
# Method:                                    Least Squares   F-statistic:                     1.227
# Date:                                   Fri, 17 May 2019   Prob (F-statistic):              0.269
# Time:                                           23:02:12   Log-Likelihood:                -570.11
# No. Observations:                                    267   AIC:                             1144.
# Df Residuals:                                        265   BIC:                             1151.
# Df Model:                                              1
# Covariance Type:                               nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept          22.2655     16.038      1.388      0.166      -9.312      53.843
# LXV_Pressure_hp    -0.0177      0.016     -1.108      0.269      -0.049       0.014
# ==============================================================================
# Omnibus:                      158.350   Durbin-Watson:                   1.956
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1009.438
# Skew:                           2.416   Prob(JB):                    6.36e-220
# Kurtosis:                      11.209   Cond. No.                     1.28e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.28e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#  ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# Intercept             5.395408
# CMtn_Dewpoint_degC    0.091754
# dtype: float64

# %% [markdown]
# #### Single Variable Summary
# **Adjusted R:**
# OLS_CMtn_Dewpoint: 0.007
# OLS_CMtnSNTL_Temp:  -0.002
# OLS_CMtn_Temperature: -0.005
# OLS_CMtn_WindSpeed:  0.017
# OLS_CMtn_CloudCover:  0.000
# OLS_CMtn_WindDirection:  -0.004
# OLS_LXV_6hr_delta_Pressure:   0.004
# OLS_LXV_Pressure:    -0.003
#
# **Prob (F-statistic):**
# OLS_CMtn_Dewpoint: 0.139
# OLS_CMtnSNTL_Temp: 0.483
# OLS_CMtn_Temperature:  0.708
# OLS_CMtn_WindSpeed:  0.0466
# OLS_CMtn_CloudCover: 0.316
# OLS_CMtn_WindDirection:   0.614
# OLS_LXV_6hr_delta_Pressure:  0.155
# OLS_LXV_Pressure:   0.550
#
# From this, we can glean that Dewpoint alone likely has the best fit as the adjusted R squared is the highest.  The F statistics such signficant correlations (at 5% confident interval) for only  Dewpoint and Pressure).

# %% [markdown]
# ## Run OLS model with all surface variables only (no filtering)

# %%
#'CMtn_1hr_Precipitation_mm', 'CMtn_6hr_Precipitation_mm'


variables = ['CMtnSNTL_Temp_degC', 'CMtn_Temperature_degC', 'CMtn_Dewpoint_degC', 'CMtn_WindDirection_deg', 'CMtn_WindSpeed_mps', 'CMtn_CloudCover_oktas', \
 'LXV_Temperature_degC', 'LXV_Dewpoint_degC', 'LXV_Pressure_hp', 'LXV_WindSpeed_mps', 'LXV_WindDirection_deg', 'LXV_CloudCover_oktas', 'LXV_12hr_delta_Pressure_hp']



from collections import OrderedDict

variables_org = variables
print(variables)

print('******')
adjRs = []
newRs = []
dup_var = []
max_vars = []
f_pvalues = []

while variables != []:
  #print(variables)
  for var in variables:

        
    #print(variables)
    max_var = max(variables, key = lambda v: ols('CMtnSNTL_Upcoming12hrSNOWFALL_gte3_in ~' + v, asos_snotel_UA_df[train_yrs]).fit().rsquared_adj)    #this finds OLS model run with highest adj R squared
    OLS = ols('CMtnSNTL_Upcoming12hrSNOWFALL_gte3_in ~' + max_var, asos_snotel_UA_df[train_yrs]).fit()
    
    print(max_var)
    #print(max_var)
    #print(OLS.rsquared)
    
    #Create lists of statistics for each combination of variables modeld
    adjRs.append(OLS.rsquared_adj)
    f_pvalues.append(OLS.f_pvalue)
    max_vars.append(max_var)

    add_max_var = '+ '+ max_var
    
    variables = [s + add_max_var for s in variables_org]
    
    #The above for loop naturally will create a duplicate variable, which should be removed
    for v in variables_org: 
      dup_var = []
      dup_var = [var for var in variables if var.count(v)>1]
      if dup_var!=[]:
            for dup in dup_var: variables.remove(dup)

#combine the modeled variable sequences with respective stats  
stats = list(zip(adjRs, f_pvalues))    # create list of tuples
dictionary = OrderedDict(zip(max_vars, stats))
#dictionary_adjRs = OrderedDict(zip(max_vars, f_pvalues))
print(adjRs)
print(max_vars)
print(f_pvalues)
print(dictionary)
# Out:
# ['CMtnSNTL_Temp_degC', 'CMtn_Temperature_degC', 'CMtn_Dewpoint_degC', 'CMtn_WindDirection_deg', 'CMtn_WindSpeed_mps', 'CMtn_CloudCover_oktas', 'LXV_Temperature_degC', 'LXV_Dewpoint_degC', 'LXV_Pressure_hp', 'LXV_WindSpeed_mps', 'LXV_WindDirection_deg', 'LXV_CloudCover_oktas', 'LXV_12hr_delta_Pressure_hp']
# ******
# CMtn_Dewpoint_degC
# CMtn_WindDirection_deg+ CMtn_Dewpoint_degC
# LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC
# LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC
# LXV_WindSpeed_mps+ LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC
# CMtn_WindSpeed_mps+ LXV_WindSpeed_mps+ LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC
# CMtn_Temperature_degC+ CMtn_WindSpeed_mps+ LXV_WindSpeed_mps+ LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC
# LXV_12hr_delta_Pressure_hp+ CMtn_Temperature_degC+ CMtn_WindSpeed_mps+ LXV_WindSpeed_mps+ LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC
# LXV_Dewpoint_degC+ LXV_12hr_delta_Pressure_hp+ CMtn_Temperature_degC+ CMtn_WindSpeed_mps+ LXV_WindSpeed_mps+ LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC
# CMtnSNTL_Temp_degC+ LXV_Dewpoint_degC+ LXV_12hr_delta_Pressure_hp+ CMtn_Temperature_degC+ CMtn_WindSpeed_mps+ LXV_WindSpeed_mps+ LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC
# LXV_CloudCover_oktas+ CMtnSNTL_Temp_degC+ LXV_Dewpoint_degC+ LXV_12hr_delta_Pressure_hp+ CMtn_Temperature_degC+ CMtn_WindSpeed_mps+ LXV_WindSpeed_mps+ LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC
# CMtn_CloudCover_oktas+ LXV_CloudCover_oktas+ CMtnSNTL_Temp_degC+ LXV_Dewpoint_degC+ LXV_12hr_delta_Pressure_hp+ CMtn_Temperature_degC+ CMtn_WindSpeed_mps+ LXV_WindSpeed_mps+ LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC
# [0.03503489946658833, 0.07540824032508964, 0.0853886357592738, 0.08774936940794154, 0.09181352372597906, 0.09092797217368631, 0.09026923972723122, 0.0874363633721188, 0.08453736328912043, 0.08008925227766983, 0.07549804470530941, 0.03339695238501128, 0.019831291064970613]
# ['CMtn_Dewpoint_degC', 'CMtn_WindDirection_deg+ CMtn_Dewpoint_degC', 'LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC', 'LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC', 'LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC', 'LXV_WindSpeed_mps+ LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC', 'CMtn_WindSpeed_mps+ LXV_WindSpeed_mps+ LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC', 'CMtn_Temperature_degC+ CMtn_WindSpeed_mps+ LXV_WindSpeed_mps+ LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC', 'LXV_12hr_delta_Pressure_hp+ CMtn_Temperature_degC+ CMtn_WindSpeed_mps+ LXV_WindSpeed_mps+ LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC', 'LXV_Dewpoint_degC+ LXV_12hr_delta_Pressure_hp+ CMtn_Temperature_degC+ CMtn_WindSpeed_mps+ LXV_WindSpeed_mps+ LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC', 'CMtnSNTL_Temp_degC+ LXV_Dewpoint_degC+ LXV_12hr_delta_Pressure_hp+ CMtn_Temperature_degC+ CMtn_WindSpeed_mps+ LXV_WindSpeed_mps+ LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC', 'LXV_CloudCover_oktas+ CMtnSNTL_Temp_degC+ LXV_Dewpoint_degC+ LXV_12hr_delta_Pressure_hp+ CMtn_Temperature_degC+ CMtn_WindSpeed_mps+ LXV_WindSpeed_mps+ LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC', 'CMtn_CloudCover_oktas+ LXV_CloudCover_oktas+ CMtnSNTL_Temp_degC+ LXV_Dewpoint_degC+ LXV_12hr_delta_Pressure_hp+ CMtn_Temperature_degC+ CMtn_WindSpeed_mps+ LXV_WindSpeed_mps+ LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC']
# [0.0026967295378235966, 9.451001336516966e-05, 7.587609030558432e-05, 0.00011685898580389155, 0.0001360421336284729, 0.00024286637264620112, 0.0003943574828127052, 0.0007366132381806371, 0.0013456278510671333, 0.0025497413162927636, 0.00460695174744788, 0.16397020786803085, 0.2728301409444965]
# OrderedDict([('CMtn_Dewpoint_degC', (0.03503489946658833, 0.0026967295378235966)), ('CMtn_WindDirection_deg+ CMtn_Dewpoint_degC', (0.07540824032508964, 9.451001336516966e-05)), ('LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC', (0.0853886357592738, 7.587609030558432e-05)), ('LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC', (0.08774936940794154, 0.00011685898580389155)), ('LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC', (0.09181352372597906, 0.0001360421336284729)), ('LXV_WindSpeed_mps+ LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC', (0.09092797217368631, 0.00024286637264620112)), ('CMtn_WindSpeed_mps+ LXV_WindSpeed_mps+ LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC', (0.09026923972723122, 0.0003943574828127052)), ('CMtn_Temperature_degC+ CMtn_WindSpeed_mps+ LXV_WindSpeed_mps+ LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC', (0.0874363633721188, 0.0007366132381806371)), ('LXV_12hr_delta_Pressure_hp+ CMtn_Temperature_degC+ CMtn_WindSpeed_mps+ LXV_WindSpeed_mps+ LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC', (0.08453736328912043, 0.0013456278510671333)), ('LXV_Dewpoint_degC+ LXV_12hr_delta_Pressure_hp+ CMtn_Temperature_degC+ CMtn_WindSpeed_mps+ LXV_WindSpeed_mps+ LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC', (0.08008925227766983, 0.0025497413162927636)), ('CMtnSNTL_Temp_degC+ LXV_Dewpoint_degC+ LXV_12hr_delta_Pressure_hp+ CMtn_Temperature_degC+ CMtn_WindSpeed_mps+ LXV_WindSpeed_mps+ LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC', (0.07549804470530941, 0.00460695174744788)), ('LXV_CloudCover_oktas+ CMtnSNTL_Temp_degC+ LXV_Dewpoint_degC+ LXV_12hr_delta_Pressure_hp+ CMtn_Temperature_degC+ CMtn_WindSpeed_mps+ LXV_WindSpeed_mps+ LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC', (0.03339695238501128, 0.16397020786803085)), ('CMtn_CloudCover_oktas+ LXV_CloudCover_oktas+ CMtnSNTL_Temp_degC+ LXV_Dewpoint_degC+ LXV_12hr_delta_Pressure_hp+ CMtn_Temperature_degC+ CMtn_WindSpeed_mps+ LXV_WindSpeed_mps+ LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC', (0.019831291064970613, 0.2728301409444965))])

# %%
plt.plot(adjRs)

# %%
plt.plot(f_pvalues)

# %% [markdown]
# ## Run OLS model with surface variables only (high data capture, filtered by UA)
# **We only want to use features with high data capture in the training years**

# %%
variables = ['CMtnSNTL_Temp_degC', 'CMtn_Temperature_degC', 'CMtn_Dewpoint_degC', 'CMtn_WindDirection_deg', 'CMtn_WindSpeed_mps', 'CMtn_CloudCover_oktas', \
 'LXV_Temperature_degC', 'LXV_Dewpoint_degC', 'LXV_Pressure_hp', 'LXV_WindSpeed_mps', 'LXV_WindDirection_deg', 'LXV_CloudCover_oktas', 'LXV_12hr_delta_Pressure_hp', \
 'KGJT_200mb_height_m', 'KGJT_200mb_tmpc', 'KGJT_200mb_dwpc', 'KGJT_200mb_drct', 'KGJT_200mb_speed_kts', \
 'KGJT_250mb_height_m', 'KGJT_250mb_tmpc', 'KGJT_250mb_dwpc', 'KGJT_250mb_drct', 'KGJT_250mb_speed_kts', \
 'KGJT_300mb_height_m', 'KGJT_300mb_tmpc', 'KGJT_300mb_dwpc', 'KGJT_300mb_drct', 'KGJT_300mb_speed_kts', \
 'KGJT_400mb_height_m', 'KGJT_400mb_tmpc', 'KGJT_400mb_dwpc', 'KGJT_400mb_drct', 'KGJT_400mb_speed_kts', \
 'KGJT_500mb_height_m', 'KGJT_500mb_tmpc', 'KGJT_500mb_dwpc', 'KGJT_500mb_drct', 'KGJT_500mb_speed_kts', \
 'KGJT_700mb_height_m', 'KGJT_700mb_tmpc', 'KGJT_700mb_dwpc', 'KGJT_700mb_drct', 'KGJT_700mb_speed_kts', \
 'KGJT_850mb_height_m', 'KGJT_850mb_tmpc', 'KGJT_850mb_dwpc', 'KGJT_850mb_drct', 'KGJT_850mb_speed_kts', \
 'KGJT_d850_700_height_m', 'KGJT_d850_700_tmpc', 'KGJT_d850_700_dwpc', 'KGJT_d850_700_drct', 'KGJT_d850_700_speed_kts', \
 'KGJT_d850_500_height_m', 'KGJT_d850_500_tmpc', 'KGJT_d850_500_dwpc', 'KGJT_d850_500_drct', 'KGJT_d850_500_speed_kts', \
 'KGJT_d850_400_height_m', 'KGJT_d850_400_tmpc', 'KGJT_d850_400_dwpc', 'KGJT_d850_400_drct', 'KGJT_d850_400_speed_kts', \
 'KGJT_d850_300_height_m', 'KGJT_d850_300_tmpc', 'KGJT_d850_300_dwpc', 'KGJT_d850_300_drct', 'KGJT_d850_300_speed_kts', \
 'KGJT_d850_250_height_m', 'KGJT_d850_250_tmpc', 'KGJT_d850_250_dwpc', 'KGJT_d850_250_drct', 'KGJT_d850_250_speed_kts', \
 'KGJT_d850_200_height_m', 'KGJT_d850_200_tmpc', 'KGJT_d850_200_dwpc', 'KGJT_d850_200_drct', 'KGJT_d850_200_speed_kts',\
 'KGJT_d700_500_height_m', 'KGJT_d700_500_tmpc', 'KGJT_d700_500_dwpc', 'KGJT_d700_500_drct', 'KGJT_d700_500_speed_kts', \
 'KGJT_d700_400_height_m', 'KGJT_d700_400_tmpc', 'KGJT_d700_400_dwpc', 'KGJT_d700_400_drct', 'KGJT_d700_400_speed_kts', \
 'KGJT_d700_300_height_m', 'KGJT_d700_300_tmpc', 'KGJT_d700_300_dwpc', 'KGJT_d700_300_drct', 'KGJT_d700_300_speed_kts', \
 'KGJT_d700_250_height_m', 'KGJT_d700_250_tmpc', 'KGJT_d700_250_dwpc', 'KGJT_d700_250_drct', 'KGJT_d700_250_speed_kts', \
 'KGJT_d700_200_height_m', 'KGJT_d700_200_tmpc', 'KGJT_d700_200_dwpc', 'KGJT_d700_200_drct', 'KGJT_d700_200_speed_kts', \
 'KGJT_d500_400_height_m', 'KGJT_d500_400_tmpc', 'KGJT_d500_400_dwpc', 'KGJT_d500_400_drct', 'KGJT_d500_400_speed_kts', \
 'KGJT_d500_300_height_m', 'KGJT_d500_300_tmpc', 'KGJT_d500_300_dwpc', 'KGJT_d500_300_drct', 'KGJT_d500_300_speed_kts', \
 'KGJT_d500_250_height_m', 'KGJT_d500_250_tmpc', 'KGJT_d500_250_dwpc', 'KGJT_d500_250_drct', 'KGJT_d500_250_speed_kts', \
 'KGJT_d500_200_height_m', 'KGJT_d500_200_tmpc', 'KGJT_d500_200_dwpc', 'KGJT_d500_200_drct', 'KGJT_d500_200_speed_kts', \
 'KGJT_d400_300_height_m', 'KGJT_d400_300_tmpc', 'KGJT_d400_300_dwpc', 'KGJT_d400_300_drct', 'KGJT_d400_300_speed_kts', \
 'KGJT_d400_250_height_m', 'KGJT_d400_250_tmpc', 'KGJT_d400_250_dwpc', 'KGJT_d400_250_drct', 'KGJT_d400_250_speed_kts', \
 'KGJT_d400_200_height_m', 'KGJT_d400_200_tmpc', 'KGJT_d400_200_dwpc', 'KGJT_d400_200_drct', 'KGJT_d400_200_speed_kts', \
 'KGJT_d300_250_height_m', 'KGJT_d300_250_tmpc', 'KGJT_d300_250_dwpc', 'KGJT_d300_250_drct', 'KGJT_d300_250_speed_kts', \
 'KGJT_d300_200_height_m', 'KGJT_d300_200_tmpc', 'KGJT_d300_200_dwpc', 'KGJT_d300_200_drct', 'KGJT_d300_200_speed_kts', \
 'KGJT_d250_200_height_m', 'KGJT_d250_200_tmpc', 'KGJT_d250_200_dwpc', 'KGJT_d250_200_drct', 'KGJT_d250_200_speed_kts']

good_vars = []
bad_vars = []
for var in variables:
    idx = np.isfinite(asos_snotel_UA_df[all_yrs]['CMtnSNTL_Upcoming12hrSNOWFALL_gte3_in']) & np.isfinite(asos_snotel_UA_df[all_yrs][var])
 #   total_poss = len(asos_snotel_UA_df[all_yrs]['CMtnSNTL_Upcoming12hrSNOWFALL_gte3_in'][asos_snotel_UA_df[all_yrs]['CMtnSNTL_Upcoming12hrSNOWFALL_gte3_in']>=0])
    
    total_poss = asos_snotel_UA_df[all_yrs]['CMtnSNTL_Upcoming12hrSNOWFALL_gte3_in'].count()   #counts only non missing values
    total_avail =len(asos_snotel_UA_df[all_yrs][idx]) 
    
    if total_avail/total_poss >= 0.67: 
        good_vars.append(var)
    else:
        bad_vars.append(var)
        
#Filter out surface data
sfc_good_vars = [k for k in good_vars if 'CMtn' in k] + [k for k in good_vars if 'LXV' in k]
        
print('SURFACE Variables with >= 67% data match to snowfall: ')
print(sfc_good_vars)
print('Variables with < 67% data match to snowfall: ')
print(bad_vars)
# Out:
# SURFACE Variables with >= 67% data match to snowfall:
# ['CMtnSNTL_Temp_degC', 'CMtn_Temperature_degC', 'CMtn_Dewpoint_degC', 'CMtn_WindDirection_deg', 'CMtn_WindSpeed_mps', 'LXV_Temperature_degC', 'LXV_Dewpoint_degC', 'LXV_Pressure_hp', 'LXV_WindSpeed_mps', 'LXV_WindDirection_deg', 'LXV_12hr_delta_Pressure_hp']
# Variables with < 67% data match to snowfall:
# ['CMtn_CloudCover_oktas', 'LXV_CloudCover_oktas', 'KGJT_850mb_tmpc', 'KGJT_850mb_dwpc', 'KGJT_850mb_drct', 'KGJT_850mb_speed_kts', 'KGJT_d850_700_tmpc', 'KGJT_d850_700_dwpc', 'KGJT_d850_700_drct', 'KGJT_d850_700_speed_kts', 'KGJT_d850_500_tmpc', 'KGJT_d850_500_dwpc', 'KGJT_d850_500_drct', 'KGJT_d850_500_speed_kts', 'KGJT_d850_400_tmpc', 'KGJT_d850_400_dwpc', 'KGJT_d850_400_drct', 'KGJT_d850_400_speed_kts', 'KGJT_d850_300_tmpc', 'KGJT_d850_300_dwpc', 'KGJT_d850_300_drct', 'KGJT_d850_300_speed_kts', 'KGJT_d850_250_tmpc', 'KGJT_d850_250_dwpc', 'KGJT_d850_250_drct', 'KGJT_d850_250_speed_kts', 'KGJT_d850_200_tmpc', 'KGJT_d850_200_dwpc', 'KGJT_d850_200_drct', 'KGJT_d850_200_speed_kts']

# %% [markdown]
# **Because we will want an apples to apples type comparision with the OLS model we perform with Surface+UA data, we must be sure sure to use the same snowfall data. **For every snowfall amount used, there must be a datapoint for every corresponding surface and upper air data features.  Therefore, any rows with an NaN value will be removed from the analysis.

# %%
good_vars_snf =[]
filtered_asos_snotel_UA_df = pd.DataFrame()


#df_sfc = asos_snotel_UA_df[['CMtnSNTL_Temp_degC', 'CMtn_Temperature_degC', 'CMtn_Dewpoint_degC', 'CMtn_WindDirection_deg', 'CMtn_WindSpeed_mps', \
#                           'LXV_Temperature_degC', 'LXV_Dewpoint_degC', 'LXV_Pressure_hp', 'LXV_WindSpeed_mps', 'LXV_WindDirection_deg', 'LXV_12hr_delta_Pressure_hp','CMtnSNTL_Upcoming12hrSNOWFALL_gte3_in']].copy()
#
#df = asos_snotel_UA_df[df = asos_snotel_UA_df[['CMtnSNTL_Temp_degC', 'CMtn_Temperature_degC', 'CMtn_Dewpoint_degC', 'CMtn_WindDirection_deg', 'CMtn_WindSpeed_mps', \
#                        'LXV_Temperature_degC', 'LXV_Dewpoint_degC', 'LXV_Pressure_hp', 'LXV_WindSpeed_mps', 'LXV_WindDirection_deg', 'LXV_12hr_delta_Pressure_hp', \
#                        'KGJT_200mb_height_m', 'KGJT_200mb_tmpc', 'KGJT_200mb_dwpc', 'KGJT_200mb_drct', 'KGJT_200mb_speed_kts', 'KGJT_250mb_height_m', 'KGJT_250mb_tmpc', \
#                        'KGJT_250mb_dwpc', 'KGJT_250mb_drct', 'KGJT_250mb_speed_kts', 'KGJT_300mb_height_m', 'KGJT_300mb_tmpc', 'KGJT_300mb_dwpc', 'KGJT_300mb_drct', \
#                        'KGJT_300mb_speed_kts', 'KGJT_400mb_height_m', 'KGJT_400mb_tmpc', 'KGJT_400mb_dwpc', 'KGJT_400mb_drct', 'KGJT_400mb_speed_kts', \
#                        'KGJT_500mb_height_m', 'KGJT_500mb_tmpc', 'KGJT_500mb_dwpc', 'KGJT_500mb_drct', 'KGJT_500mb_speed_kts', 'KGJT_700mb_height_m', \
#                        'KGJT_700mb_tmpc', 'KGJT_700mb_dwpc', 'KGJT_700mb_drct', 'KGJT_700mb_speed_kts', 'KGJT_850mb_height_m', 'KGJT_d850_700_height_m', \
#                        'KGJT_d850_500_height_m', 'KGJT_d850_400_height_m', 'KGJT_d850_300_height_m', 'KGJT_d850_250_height_m', 'KGJT_d850_200_height_m', 'KGJT_d700_500_height_m', 'KGJT_d700_500_tmpc', 'KGJT_d700_500_dwpc', 'KGJT_d700_500_drct', 'KGJT_d700_500_speed_kts', 'KGJT_d700_400_height_m', 'KGJT_d700_400_tmpc', 'KGJT_d700_400_dwpc', 'KGJT_d700_400_drct', 'KGJT_d700_400_speed_kts', 'KGJT_d700_300_height_m', 'KGJT_d700_300_tmpc', 'KGJT_d700_300_dwpc', 'KGJT_d700_300_drct', 'KGJT_d700_300_speed_kts', 'KGJT_d700_250_height_m', 'KGJT_d700_250_tmpc', 'KGJT_d700_250_dwpc', 'KGJT_d700_250_drct', 'KGJT_d700_250_speed_kts', 'KGJT_d700_200_height_m', 'KGJT_d700_200_tmpc', 'KGJT_d700_200_dwpc', 'KGJT_d700_200_drct', 'KGJT_d700_200_speed_kts', 'KGJT_d500_400_height_m', 'KGJT_d500_400_tmpc', 'KGJT_d500_400_dwpc', 'KGJT_d500_400_drct', 'KGJT_d500_400_speed_kts', 'KGJT_d500_300_height_m', 'KGJT_d500_300_tmpc', 'KGJT_d500_300_dwpc', 'KGJT_d500_300_drct', 'KGJT_d500_300_speed_kts', 'KGJT_d500_250_height_m', 'KGJT_d500_250_tmpc', 'KGJT_d500_250_dwpc', 'KGJT_d500_250_drct', 'KGJT_d500_250_speed_kts', 'KGJT_d500_200_height_m', 'KGJT_d500_200_tmpc', 'KGJT_d500_200_dwpc', 'KGJT_d500_200_drct', 'KGJT_d500_200_speed_kts', 'KGJT_d400_300_height_m', 'KGJT_d400_300_tmpc', 'KGJT_d400_300_dwpc', 'KGJT_d400_300_drct', 'KGJT_d400_300_speed_kts', 'KGJT_d400_250_height_m', 'KGJT_d400_250_tmpc', 'KGJT_d400_250_dwpc', 'KGJT_d400_250_drct', 'KGJT_d400_250_speed_kts', 'KGJT_d400_200_height_m', 'KGJT_d400_200_tmpc', 'KGJT_d400_200_dwpc', 'KGJT_d400_200_drct', 'KGJT_d400_200_speed_kts', 'KGJT_d300_250_height_m', 'KGJT_d300_250_tmpc', 'KGJT_d300_250_dwpc', 'KGJT_d300_250_drct', 'KGJT_d300_250_speed_kts', 'KGJT_d300_200_height_m', 'KGJT_d300_200_tmpc', 'KGJT_d300_200_dwpc', 'KGJT_d300_200_drct', 'KGJT_d300_200_speed_kts', \
#                        'KGJT_d250_200_height_m', 'KGJT_d250_200_tmpc', 'KGJT_d250_200_dwpc', 'KGJT_d250_200_drct', \
#                         'KGJT_d250_200_speed_kts','CMtnSNTL_Upcoming12hrSNOWFALL_gte3_in']].copy()

good_vars_snf = sfc_good_vars + ['CMtnSNTL_Upcoming12hrSNOWFALL_gte3_in']
print(good_vars_snf )
filtered_asos_snotel_UA_df=  asos_snotel_UA_df[good_vars_snf].copy()
test_train_df = asos_snotel_UA_df[good_vars_snf].dropna()
#test_df = asos_snotel_UA_df[good_vars_snf][test_yrs].dropna()
#train_df = asos_snotel_UA_df[good_vars_snf][train_yrs].dropna()

#print(test_df.describe())
#print(train_df.describe())
#print(filtered_asos_snotel_UA_df[train_yrs].dropna().describe())
print(test_train_df)
# Out:
# ['CMtnSNTL_Temp_degC', 'CMtn_Temperature_degC', 'CMtn_Dewpoint_degC', 'CMtn_WindDirection_deg', 'CMtn_WindSpeed_mps', 'LXV_Temperature_degC', 'LXV_Dewpoint_degC', 'LXV_Pressure_hp', 'LXV_WindSpeed_mps', 'LXV_WindDirection_deg', 'LXV_12hr_delta_Pressure_hp', 'CMtnSNTL_Upcoming12hrSNOWFALL_gte3_in']
#                            CMtnSNTL_Temp_degC  CMtn_Temperature_degC  \
# Date_Time
# 2006-01-01 12:00:00+00:00                -3.2                  -7.00
# 2006-01-08 12:00:00+00:00                -6.2                  -9.00
# 2006-01-12 12:00:00+00:00                -8.2                  -9.00
# 2006-01-18 00:00:00+00:00                -8.0                  -9.00
# 2006-01-19 00:00:00+00:00                -4.3                  -8.00
# 2006-01-29 00:00:00+00:00                -9.7                 -14.00
# 2006-02-02 00:00:00+00:00                -4.3                  -8.00
# 2006-02-05 00:00:00+00:00                -5.3                  -6.00
# 2006-03-09 12:00:00+00:00               -14.7                 -16.00
# 2006-03-30 00:00:00+00:00                -0.8                  -4.00
# 2006-04-02 00:00:00+00:00                -0.7                  -4.00
# 2006-04-07 00:00:00+00:00                -5.1                  -8.00
# 2006-04-15 00:00:00+00:00                 5.2                   4.00
# 2006-09-21 00:00:00+00:00                 1.6                   2.00
# 2006-09-22 00:00:00+00:00                -0.4                  -3.00
# 2006-10-17 12:00:00+00:00                -5.4                  -3.00
# 2006-10-20 12:00:00+00:00                -2.2                  -6.00
# 2006-10-26 00:00:00+00:00                -0.8                  -1.00
# 2006-11-13 12:00:00+00:00                -8.5                  -7.00
# 2006-11-14 12:00:00+00:00                -2.7                  -6.00
# 2006-11-28 00:00:00+00:00                -4.1                  -8.00
# 2006-11-28 12:00:00+00:00                -6.8                  -9.00
# 2006-12-01 12:00:00+00:00                -9.8                 -12.00
# 2006-12-12 00:00:00+00:00                -7.9                 -11.00
# 2006-12-24 12:00:00+00:00                -9.5                  -9.00
# 2007-01-05 00:00:00+00:00                -0.6                  -5.00
# 2007-02-20 00:00:00+00:00                -3.2                  -7.00
# 2007-02-28 00:00:00+00:00                -5.0                  -8.00
# 2007-03-08 12:00:00+00:00                -4.6                  -4.00
# 2007-03-10 12:00:00+00:00                -3.5                  -5.00
# ...                                       ...                    ...
# 2016-03-23 00:00:00+00:00                -0.6                   0.00
# 2016-03-25 12:00:00+00:00                -5.7                  -7.00
# 2016-03-30 00:00:00+00:00                -3.2                  -2.00
# 2016-04-05 12:00:00+00:00                 2.7                   1.00
# 2017-03-28 00:00:00+00:00                                    3.0
# 2017-03-28 12:00:00+00:00                                    4.0
# 2017-03-31 12:00:00+00:00                                    3.0
# 2017-04-04 00:00:00+00:00                                    3.0
# 2017-04-04 12:00:00+00:00                                    3.0
# 2017-04-22 00:00:00+00:00                                    3.0
# 2017-04-25 00:00:00+00:00                                    3.0
# 2017-04-27 00:00:00+00:00                                    5.0
# 2017-04-28 00:00:00+00:00                                    3.0
# 2017-05-18 00:00:00+00:00                                   16.0
# 2017-05-18 12:00:00+00:00                                    6.0
# 2017-10-02 00:00:00+00:00                                   11.0
# 2017-10-21 00:00:00+00:00                                    3.0
# 2017-11-18 00:00:00+00:00                                    8.0
# 2017-11-21 00:00:00+00:00                                    3.0
# 2017-12-04 00:00:00+00:00                                    5.0
#
# [274 rows x 12 columns]

# %%
import statistics as sts
all_yrs_tt = (test_train_df.index >= '01-01-2006') & (test_train_df.index < '01-01-2018')
train_yrs_tt=  ((test_train_df.index >= '01-01-2006') & (test_train_df.index < '01-01-2013')) | ((test_train_df.index >= '01-01-2015') & (test_train_df.index < '01-01-2018'))
test_yrs_tt = (test_train_df.index >= '01-01-2013') & (test_train_df.index < '01-01-2015')

# %% [markdown]
# ### Run model with good SURFACE variables

# %%
from collections import OrderedDict

variables = ['CMtnSNTL_Temp_degC', 'CMtn_Temperature_degC', 'CMtn_Dewpoint_degC', \
'CMtn_WindDirection_deg', 'CMtn_WindSpeed_mps', 'LXV_Temperature_degC', 'LXV_Dewpoint_degC', \
'LXV_Pressure_hp', 'LXV_WindSpeed_mps', 'LXV_WindDirection_deg', 'LXV_12hr_delta_Pressure_hp']
variables_org = variables
print(variables)

print('******')
adjRs = []
newRs = []
dup_var = []
max_vars = []
f_pvalues = []

while variables != []:
  #print(variables)
  for var in variables:

        
    #print(variables)
    max_var = max(variables, key = lambda v: ols('CMtnSNTL_Upcoming12hrSNOWFALL_gte3_in ~' + v, test_train_df[train_yrs_tt]).fit().rsquared_adj)    #this finds OLS model run with highest adj R squared
    OLS = ols('CMtnSNTL_Upcoming12hrSNOWFALL_gte3_in ~' + max_var, test_train_df[train_yrs_tt]).fit()
    
    print(max_var)
    #print(max_var)
    #print(OLS.rsquared)
    
    #Create lists of statistics for each combination of variables modeld
    adjRs.append(OLS.rsquared_adj)
    f_pvalues.append(OLS.f_pvalue)
    max_vars.append(max_var)

    add_max_var = '+ '+ max_var
    
    variables = [s + add_max_var for s in variables_org]
    
    #The above for loop naturally will create a duplicate variable, which should be removed
    for v in variables_org: 
      dup_var = []
      dup_var = [var for var in variables if var.count(v)>1]
      if dup_var!=[]:
            for dup in dup_var: variables.remove(dup)

#combine the modeled variable sequences with respective stats  
stats = list(zip(adjRs, f_pvalues))    # create list of tuples
dictionary = OrderedDict(zip(max_vars, stats))
#dictionary_adjRs = OrderedDict(zip(max_vars, f_pvalues))
print(adjRs)
print(max_vars)
print(f_pvalues)
print(dictionary)
# Out:
# ['CMtnSNTL_Temp_degC', 'CMtn_Temperature_degC', 'CMtn_Dewpoint_degC', 'CMtn_WindDirection_deg', 'CMtn_WindSpeed_mps', 'LXV_Temperature_degC', 'LXV_Dewpoint_degC', 'LXV_Pressure_hp', 'LXV_WindSpeed_mps', 'LXV_WindDirection_deg', 'LXV_12hr_delta_Pressure_hp']
# ******
# CMtn_Dewpoint_degC
# CMtn_WindDirection_deg+ CMtn_Dewpoint_degC
# LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC
# LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC
# LXV_WindSpeed_mps+ LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC
# CMtn_WindSpeed_mps+ LXV_WindSpeed_mps+ LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC
# CMtn_Temperature_degC+ CMtn_WindSpeed_mps+ LXV_WindSpeed_mps+ LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC
# LXV_12hr_delta_Pressure_hp+ CMtn_Temperature_degC+ CMtn_WindSpeed_mps+ LXV_WindSpeed_mps+ LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC
# LXV_Dewpoint_degC+ LXV_12hr_delta_Pressure_hp+ CMtn_Temperature_degC+ CMtn_WindSpeed_mps+ LXV_WindSpeed_mps+ LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC
# CMtnSNTL_Temp_degC+ LXV_Dewpoint_degC+ LXV_12hr_delta_Pressure_hp+ CMtn_Temperature_degC+ CMtn_WindSpeed_mps+ LXV_WindSpeed_mps+ LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC
# [0.06192802819147314, 0.0727053561548946, 0.08510592138204931, 0.0874426246941542, 0.09161164285350953, 0.0907143055469789, 0.08998507549651635, 0.08707951736903707, 0.08453736328912043, 0.08008925227766983, 0.07549804470530941]
# ['CMtn_Dewpoint_degC', 'CMtn_WindDirection_deg+ CMtn_Dewpoint_degC', 'LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC', 'LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC', 'LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC', 'LXV_WindSpeed_mps+ LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC', 'CMtn_WindSpeed_mps+ LXV_WindSpeed_mps+ LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC', 'CMtn_Temperature_degC+ CMtn_WindSpeed_mps+ LXV_WindSpeed_mps+ LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC', 'LXV_12hr_delta_Pressure_hp+ CMtn_Temperature_degC+ CMtn_WindSpeed_mps+ LXV_WindSpeed_mps+ LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC', 'LXV_Dewpoint_degC+ LXV_12hr_delta_Pressure_hp+ CMtn_Temperature_degC+ CMtn_WindSpeed_mps+ LXV_WindSpeed_mps+ LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC', 'CMtnSNTL_Temp_degC+ LXV_Dewpoint_degC+ LXV_12hr_delta_Pressure_hp+ CMtn_Temperature_degC+ CMtn_WindSpeed_mps+ LXV_WindSpeed_mps+ LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC']
# [0.00014870524276832092, 0.00013868367017196522, 8.167230192307862e-05, 0.00012589464009109448, 0.00014494148408361786, 0.00025832672543203174, 0.0004211655575910531, 0.0007887232121564379, 0.0013456278510671333, 0.0025497413162927636, 0.00460695174744788]
# OrderedDict([('CMtn_Dewpoint_degC', (0.06192802819147314, 0.00014870524276832092)), ('CMtn_WindDirection_deg+ CMtn_Dewpoint_degC', (0.0727053561548946, 0.00013868367017196522)), ('LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC', (0.08510592138204931, 8.167230192307862e-05)), ('LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC', (0.0874426246941542, 0.00012589464009109448)), ('LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC', (0.09161164285350953, 0.00014494148408361786)), ('LXV_WindSpeed_mps+ LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC', (0.0907143055469789, 0.00025832672543203174)), ('CMtn_WindSpeed_mps+ LXV_WindSpeed_mps+ LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC', (0.08998507549651635, 0.0004211655575910531)), ('CMtn_Temperature_degC+ CMtn_WindSpeed_mps+ LXV_WindSpeed_mps+ LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC', (0.08707951736903707, 0.0007887232121564379)), ('LXV_12hr_delta_Pressure_hp+ CMtn_Temperature_degC+ CMtn_WindSpeed_mps+ LXV_WindSpeed_mps+ LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC', (0.08453736328912043, 0.0013456278510671333)), ('LXV_Dewpoint_degC+ LXV_12hr_delta_Pressure_hp+ CMtn_Temperature_degC+ CMtn_WindSpeed_mps+ LXV_WindSpeed_mps+ LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC', (0.08008925227766983, 0.0025497413162927636)), ('CMtnSNTL_Temp_degC+ LXV_Dewpoint_degC+ LXV_12hr_delta_Pressure_hp+ CMtn_Temperature_degC+ CMtn_WindSpeed_mps+ LXV_WindSpeed_mps+ LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC', (0.07549804470530941, 0.00460695174744788))])

# %%
plt.plot(adjRs)

# %%
plt.plot(f_pvalues)

# %% [markdown]
# **Print adjusted R and F stat probabilities in order**

# %%
for c in dictionary:
    #print(str(dictionary.keys().index(c))+"{country}: {capital}".format(country=c, capital=dictionary[c])+"\n")
        print(str(list(dictionary.keys()).index(c))+ " {key} \n Adjusted R: {adjR}  Fstat(prob): {f_pvalue}".format(key=c, adjR=dictionary[c][0], f_pvalue = dictionary[c][1])+"\n")
        OLS = ols('CMtnSNTL_Upcoming12hrSNOWFALL_gte3_in ~' + c, test_train_df[train_yrs_tt]).fit()
# Out:
# 0 CMtn_Dewpoint_degC
#  Adjusted R: 0.06192802819147314  Fstat(prob): 0.00014870524276832092
#
# 1 CMtn_WindDirection_deg+ CMtn_Dewpoint_degC
#  Adjusted R: 0.0727053561548946  Fstat(prob): 0.00013868367017196522
#
# 2 LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC
#  Adjusted R: 0.08510592138204931  Fstat(prob): 8.167230192307862e-05
#
# 3 LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC
#  Adjusted R: 0.0874426246941542  Fstat(prob): 0.00012589464009109448
#
# 4 LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC
#  Adjusted R: 0.09161164285350953  Fstat(prob): 0.00014494148408361786
#
# 5 LXV_WindSpeed_mps+ LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC
#  Adjusted R: 0.0907143055469789  Fstat(prob): 0.00025832672543203174
#
# 6 CMtn_WindSpeed_mps+ LXV_WindSpeed_mps+ LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC
#  Adjusted R: 0.08998507549651635  Fstat(prob): 0.0004211655575910531
#
# 7 CMtn_Temperature_degC+ CMtn_WindSpeed_mps+ LXV_WindSpeed_mps+ LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC
#  Adjusted R: 0.08707951736903707  Fstat(prob): 0.0007887232121564379
#
# 8 LXV_12hr_delta_Pressure_hp+ CMtn_Temperature_degC+ CMtn_WindSpeed_mps+ LXV_WindSpeed_mps+ LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC
#  Adjusted R: 0.08453736328912043  Fstat(prob): 0.0013456278510671333
#
# 9 LXV_Dewpoint_degC+ LXV_12hr_delta_Pressure_hp+ CMtn_Temperature_degC+ CMtn_WindSpeed_mps+ LXV_WindSpeed_mps+ LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC
#  Adjusted R: 0.08008925227766983  Fstat(prob): 0.0025497413162927636
#
# 10 CMtnSNTL_Temp_degC+ LXV_Dewpoint_degC+ LXV_12hr_delta_Pressure_hp+ CMtn_Temperature_degC+ CMtn_WindSpeed_mps+ LXV_WindSpeed_mps+ LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC
#  Adjusted R: 0.07549804470530941  Fstat(prob): 0.00460695174744788

# %% [markdown]
# **Find max adj R and obtain OLS summary**

# %%
 # Just use 'min' instead of 'max' for minimum.
print("Print maximum:")
maximum = max(dictionary, key=dictionary.get) 
print(maximum)
# Out:
# Print maximum:
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC

# %%
maximum_all_str = max(dictionary, key=dictionary.get) 
print(maximum_all_str)

maxOLS_all = ols('CMtnSNTL_Upcoming12hrSNOWFALL_gte3_in ~' + maximum_all_str , asos_snotel_UA_df[train_yrs]).fit() 
print(maxOLS_all.summary())
# Out:
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC
#                                       OLS Regression Results
# =================================================================================================
# Dep. Variable:     CMtnSNTL_Upcoming12hrSNOWFALL_gte3_in   R-squared:                       0.113
# Model:                                               OLS   Adj. R-squared:                  0.092
# Method:                                    Least Squares   F-statistic:                     5.286
# Date:                                   Fri, 17 May 2019   Prob (F-statistic):           0.000136
# Time:                                           23:03:34   Log-Likelihood:                -428.32
# No. Observations:                                    213   AIC:                             868.6
# Df Residuals:                                        207   BIC:                             888.8
# Df Model:                                              5
# Covariance Type:                               nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                 36.8030     16.986      2.167      0.031       3.315      70.291
# LXV_Temperature_degC       0.0434      0.031      1.390      0.166      -0.018       0.105
# LXV_WindDirection_deg     -0.0015      0.001     -1.457      0.147      -0.003       0.001
# LXV_Pressure_hp           -0.0323      0.017     -1.893      0.060      -0.066       0.001
# CMtn_WindDirection_deg     0.0061      0.002      2.714      0.007       0.002       0.011
# CMtn_Dewpoint_degC         0.0954      0.034      2.842      0.005       0.029       0.162
# ==============================================================================
# Omnibus:                       93.152   Durbin-Watson:                   1.929
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              363.288
# Skew:                           1.769   Prob(JB):                     1.30e-79
# Kurtosis:                       8.331   Cond. No.                     1.42e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.42e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# **Print QQ plot**

# %% [markdown]
# Let's test different P|t| thresholds for which to remove variables, rerun and model for each set of variables, and see what threshold might glean best results using adjusted R squared as a metric**

# %%
rsq_adj = 0
thresh = 0

goodp_str = ""
highp_var = []

maximum_all_str = max(dictionary, key=dictionary.get)    #this is the string of variables found in previous OLS run associated with mad adjusted R squared.
print(maximum_all_str)


for test_thresh in range(1, 100):   #loop through different P|t| thresholds ranging from 1 to 100.  Note floats are not allowed here 
  print(test_thresh)
  highp_var = [var for var in maxOLS_all.pvalues.keys() if maxOLS_all.pvalues[var]>=test_thresh*0.01]  #check P|t| for each variable against threshold and store in list
  
  testgoodp_str = maximum_all_str   #reset testgoodp_str 
    
  for var in highp_var:
    testgoodp_str = testgoodp_str.replace("+ " + var, "")   #  
     

 

  maxOLS_testgoodp = ols('CMtnSNTL_Upcoming12hrSNOWFALL_gte3_in ~' + testgoodp_str, asos_snotel_UA_df[train_yrs]).fit()
  print(testgoodp_str, maxOLS_testgoodp.rsquared_adj, test_thresh*0.01)
  #print(maxOLS_testgoodp.rsquared_adj)
  if maxOLS_testgoodp.rsquared_adj > rsq_adj:
      rsq_adj = maxOLS_testgoodp.rsquared_adj
      print(maxOLS_testgoodp.rsquared_adj, test_thresh*0.01)
      goodp_str = testgoodp_str
      thresh = test_thresh*0.01

    
print("\n best threshold is:" + str(thresh))
maxOLS_goodp = ols('CMtnSNTL_Upcoming12hrSNOWFALL_gte3_in ~' + goodp_str, asos_snotel_UA_df[train_yrs]).fit() 
print(maxOLS_goodp.summary())
# Out:
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC
# 1
# LXV_Temperature_degC+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.07810699189548564 0.01
# 0.07810699189548564 0.01
# 2
# LXV_Temperature_degC+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.07810699189548564 0.02
# 3
# LXV_Temperature_degC+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.07810699189548564 0.03
# 4
# LXV_Temperature_degC+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.07810699189548564 0.04
# 5
# LXV_Temperature_degC+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.07810699189548564 0.05
# 6
# LXV_Temperature_degC+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.08690768796482717 0.06
# 0.08690768796482717 0.06
# 7
# LXV_Temperature_degC+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.08690768796482717 0.07
# 8
# LXV_Temperature_degC+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.08690768796482717 0.08
# 9
# LXV_Temperature_degC+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.08690768796482717 0.09
# 10
# LXV_Temperature_degC+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.08690768796482717 0.1
# 11
# LXV_Temperature_degC+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.08690768796482717 0.11
# 12
# LXV_Temperature_degC+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.08690768796482717 0.12
# 13
# LXV_Temperature_degC+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.08690768796482717 0.13
# 14
# LXV_Temperature_degC+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.08690768796482717 0.14
# 15
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.15
# 0.09181352372597906 0.15
# 16
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.16
# 17
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.17
# 18
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.18
# 19
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.19
# 20
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.2
# 21
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.21
# 22
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.22
# 23
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.23
# 24
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.24
# 25
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.25
# 26
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.26
# 27
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.27
# 28
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.28
# 29
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.29
# 30
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.3
# 31
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.31
# 32
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.32
# 33
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.33
# 34
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.34
# 35
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.35000000000000003
# 36
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.36
# 37
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.37
# 38
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.38
# 39
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.39
# 40
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.4
# 41
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.41000000000000003
# 42
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.42
# 43
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.43
# 44
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.44
# 45
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.45
# 46
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.46
# 47
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.47000000000000003
# 48
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.48
# 49
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.49
# 50
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.5
# 51
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.51
# 52
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.52
# 53
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.53
# 54
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.54
# 55
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.55
# 56
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.56
# 57
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.5700000000000001
# 58
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.58
# 59
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.59
# 60
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.6
# 61
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.61
# 62
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.62
# 63
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.63
# 64
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.64
# 65
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.65
# 66
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.66
# 67
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.67
# 68
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.68
# 69
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.6900000000000001
# 70
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.7000000000000001
# 71
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.71
# 72
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.72
# 73
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.73
# 74
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.74
# 75
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.75
# 76
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.76
# 77
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.77
# 78
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.78
# 79
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.79
# 80
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.8
# 81
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.81
# 82
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.8200000000000001
# 83
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.8300000000000001
# 84
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.84
# 85
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.85
# 86
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.86
# 87
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.87
# 88
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.88
# 89
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.89
# 90
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.9
# 91
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.91
# 92
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.92
# 93
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.93
# 94
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.9400000000000001
# 95
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.9500000000000001
# 96
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.96
# 97
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.97
# 98
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.98
# 99
# LXV_Temperature_degC+ LXV_WindDirection_deg+ LXV_Pressure_hp+ CMtn_WindDirection_deg+ CMtn_Dewpoint_degC 0.09181352372597906 0.99
#
#  best threshold is:0.15
#                                       OLS Regression Results
# =================================================================================================
# Dep. Variable:     CMtnSNTL_Upcoming12hrSNOWFALL_gte3_in   R-squared:                       0.113
# Model:                                               OLS   Adj. R-squared:                  0.092
# Method:                                    Least Squares   F-statistic:                     5.286
# Date:                                   Fri, 17 May 2019   Prob (F-statistic):           0.000136
# Time:                                           23:03:43   Log-Likelihood:                -428.32
# No. Observations:                                    213   AIC:                             868.6
# Df Residuals:                                        207   BIC:                             888.8
# Df Model:                                              5
# Covariance Type:                               nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                 36.8030     16.986      2.167      0.031       3.315      70.291
# LXV_Temperature_degC       0.0434      0.031      1.390      0.166      -0.018       0.105
# LXV_WindDirection_deg     -0.0015      0.001     -1.457      0.147      -0.003       0.001
# LXV_Pressure_hp           -0.0323      0.017     -1.893      0.060      -0.066       0.001
# CMtn_WindDirection_deg     0.0061      0.002      2.714      0.007       0.002       0.011
# CMtn_Dewpoint_degC         0.0954      0.034      2.842      0.005       0.029       0.162
# ==============================================================================
# Omnibus:                       93.152   Durbin-Watson:                   1.929
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              363.288
# Skew:                           1.769   Prob(JB):                     1.30e-79
# Kurtosis:                       8.331   Cond. No.                     1.42e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.42e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
import csv
actual_snf = test_train_df[test_yrs_tt]['CMtnSNTL_Upcoming12hrSNOWFALL_gte3_in'][test_train_df[test_yrs_tt]['CMtnSNTL_Upcoming12hrSNOWFALL_gte3_in']>=3]
predict_snf = maxOLS_goodp.predict(test_train_df[test_yrs_tt][test_train_df[test_yrs_tt]['CMtnSNTL_Upcoming12hrSNOWFALL_gte3_in']>=3])

rows = zip(actual_snf, predict_snf)

with open('C:/Users/RAPP/Documents/Capstone/Analysis Notebooks/B0-SFC_2014Train_OLS.csv', "w") as f:
    writer = csv.writer(f)
    for row in rows:
        writer.writerow(row)

# %% [markdown]
# **So it looks like the best P|t| threshold for variable elimination is 0.27.  A small improvement to adjusted R squared was made**

# %%
fig = plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(maxOLS_goodp, 'CMtn_WindDirection_deg', fig=fig)
