# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime as dtb
import os
from glob import glob
import datetime
import seaborn as sns
import sys

data = [pd.read_csv('C:/Users/RAPP/Documents/Capstone/HOUREMIS3_file_1-29.dat', \
                    dtype = {'SO': 'str', 'PATH': 'str', 'YEAR': 'int', 'MM': 'str', 'DD': 'str', 'HH':'str','SRC': 'str', 'RATE': 'float32', 'TEMP': 'float32' ,'VEL': 'float32'}, header = 0, delim_whitespace = True)]
#data = [pd.read_csv('C:/Users/RAPP/Documents/Capstone/HOUREMIS3_file_1-29.dat', header = 0, delimiter = " ")]

df = pd.concat(data)

# %% [markdown]
# Create NE dataframe such that operating 2013-2014

# %%
NE_2yr_df = pd.DataFrame()
NE_2yr_df = df.copy()
print(NE_2yr_df['RATE'].describe())
xx = ((NE_2yr_df['YEAR'] <= 2014))
plt.plot(xx)
NE_2yr_df['RATE'][xx] = 0


#plt.plot(NE_df['RATE'])
print(NE_2yr_df['RATE'].describe())
NE_2yr_df['SRC'] = ['NE_'+ str(col) for col in NE_2yr_df['SRC'] ]



print(NE_2yr_df)
# Out:
# count    350592.000000
# mean          0.084472
# std           0.408184
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           2.571000
# Name: RATE, dtype: float64
# count    350592.000000
# mean          0.050683
# std           0.318875
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           2.571000
# Name: RATE, dtype: float64
# c:\users\rapp\appdata\local\programs\python\python36-32\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#         SO      PATH  YEAR  MM  DD  HH       SRC  RATE  TEMP  VEL
# 0       SO  HOUREMIS  2013  01  01  01  NE_FRAC1   0.0   0.0  0.0
# 1       SO  HOUREMIS  2013  01  01  01  NE_FRAC2   0.0   0.0  0.0
# 2       SO  HOUREMIS  2013  01  01  01  NE_FRAC3   0.0   0.0  0.0
# 3       SO  HOUREMIS  2013  01  01  01  NE_FRAC4   0.0   0.0  0.0
# 4       SO  HOUREMIS  2013  01  01  01  NE_FRAC5   0.0   0.0  0.0
# 5       SO  HOUREMIS  2013  01  01  01  NE_FRAC6   0.0   0.0  0.0
# 6       SO  HOUREMIS  2013  01  01  01  NE_FRAC7   0.0   0.0  0.0
# 7       SO  HOUREMIS  2013  01  01  01  NE_FRAC8   0.0   0.0  0.0
# 8       SO  HOUREMIS  2013  01  01  02  NE_FRAC1   0.0   0.0  0.0
# 9       SO  HOUREMIS  2013  01  01  02  NE_FRAC2   0.0   0.0  0.0
# 10      SO  HOUREMIS  2013  01  01  02  NE_FRAC3   0.0   0.0  0.0
# 11      SO  HOUREMIS  2013  01  01  02  NE_FRAC4   0.0   0.0  0.0
# 12      SO  HOUREMIS  2013  01  01  02  NE_FRAC5   0.0   0.0  0.0
# 13      SO  HOUREMIS  2013  01  01  02  NE_FRAC6   0.0   0.0  0.0
# 14      SO  HOUREMIS  2013  01  01  02  NE_FRAC7   0.0   0.0  0.0
# 15      SO  HOUREMIS  2013  01  01  02  NE_FRAC8   0.0   0.0  0.0
# 16      SO  HOUREMIS  2013  01  01  03  NE_FRAC1   0.0   0.0  0.0
# 17      SO  HOUREMIS  2013  01  01  03  NE_FRAC2   0.0   0.0  0.0
# 18      SO  HOUREMIS  2013  01  01  03  NE_FRAC3   0.0   0.0  0.0
# 19      SO  HOUREMIS  2013  01  01  03  NE_FRAC4   0.0   0.0  0.0
# 20      SO  HOUREMIS  2013  01  01  03  NE_FRAC5   0.0   0.0  0.0
# 21      SO  HOUREMIS  2013  01  01  03  NE_FRAC6   0.0   0.0  0.0
# 22      SO  HOUREMIS  2013  01  01  03  NE_FRAC7   0.0   0.0  0.0
# 23      SO  HOUREMIS  2013  01  01  03  NE_FRAC8   0.0   0.0  0.0
# 24      SO  HOUREMIS  2013  01  01  04  NE_FRAC1   0.0   0.0  0.0
# 25      SO  HOUREMIS  2013  01  01  04  NE_FRAC2   0.0   0.0  0.0
# 26      SO  HOUREMIS  2013  01  01  04  NE_FRAC3   0.0   0.0  0.0
# 27      SO  HOUREMIS  2013  01  01  04  NE_FRAC4   0.0   0.0  0.0
# 28      SO  HOUREMIS  2013  01  01  04  NE_FRAC5   0.0   0.0  0.0
# 29      SO  HOUREMIS  2013  01  01  04  NE_FRAC6   0.0   0.0  0.0
# ...     ..       ...   ...  ..  ..  ..       ...   ...   ...  ...
# 350562  SO  HOUREMIS  2017  12  31  21  NE_FRAC3   0.0   0.0  0.0
# 350563  SO  HOUREMIS  2017  12  31  21  NE_FRAC4   0.0   0.0  0.0
# 350564  SO  HOUREMIS  2017  12  31  21  NE_FRAC5   0.0   0.0  0.0
# 350565  SO  HOUREMIS  2017  12  31  21  NE_FRAC6   0.0   0.0  0.0
# 350566  SO  HOUREMIS  2017  12  31  21  NE_FRAC7   0.0   0.0  0.0
# 350567  SO  HOUREMIS  2017  12  31  21  NE_FRAC8   0.0   0.0  0.0
# 350568  SO  HOUREMIS  2017  12  31  22  NE_FRAC1   0.0   0.0  0.0
# 350569  SO  HOUREMIS  2017  12  31  22  NE_FRAC2   0.0   0.0  0.0
# 350570  SO  HOUREMIS  2017  12  31  22  NE_FRAC3   0.0   0.0  0.0
# 350571  SO  HOUREMIS  2017  12  31  22  NE_FRAC4   0.0   0.0  0.0
# 350572  SO  HOUREMIS  2017  12  31  22  NE_FRAC5   0.0   0.0  0.0
# 350573  SO  HOUREMIS  2017  12  31  22  NE_FRAC6   0.0   0.0  0.0
# 350574  SO  HOUREMIS  2017  12  31  22  NE_FRAC7   0.0   0.0  0.0
# 350575  SO  HOUREMIS  2017  12  31  22  NE_FRAC8   0.0   0.0  0.0
# 350576  SO  HOUREMIS  2017  12  31  23  NE_FRAC1   0.0   0.0  0.0
# 350577  SO  HOUREMIS  2017  12  31  23  NE_FRAC2   0.0   0.0  0.0
# 350578  SO  HOUREMIS  2017  12  31  23  NE_FRAC3   0.0   0.0  0.0
# 350579  SO  HOUREMIS  2017  12  31  23  NE_FRAC4   0.0   0.0  0.0
# 350580  SO  HOUREMIS  2017  12  31  23  NE_FRAC5   0.0   0.0  0.0
# 350581  SO  HOUREMIS  2017  12  31  23  NE_FRAC6   0.0   0.0  0.0
# 350582  SO  HOUREMIS  2017  12  31  23  NE_FRAC7   0.0   0.0  0.0
# 350583  SO  HOUREMIS  2017  12  31  23  NE_FRAC8   0.0   0.0  0.0
# 350584  SO  HOUREMIS  2017  12  31  24  NE_FRAC1   0.0   0.0  0.0
# 350585  SO  HOUREMIS  2017  12  31  24  NE_FRAC2   0.0   0.0  0.0
# 350586  SO  HOUREMIS  2017  12  31  24  NE_FRAC3   0.0   0.0  0.0
# 350587  SO  HOUREMIS  2017  12  31  24  NE_FRAC4   0.0   0.0  0.0
# 350588  SO  HOUREMIS  2017  12  31  24  NE_FRAC5   0.0   0.0  0.0
# 350589  SO  HOUREMIS  2017  12  31  24  NE_FRAC6   0.0   0.0  0.0
# 350590  SO  HOUREMIS  2017  12  31  24  NE_FRAC7   0.0   0.0  0.0
# 350591  SO  HOUREMIS  2017  12  31  24  NE_FRAC8   0.0   0.0  0.0
#
# [350592 rows x 10 columns]

# %% [markdown]
# Create NW dataframe such that only operating 2015-2017

# %%
NW_3yr_df = pd.DataFrame()
NW_3yr_df = df.copy()
print(NW_3yr_df['RATE'].describe())
#plt.plot(NW_df['RATE'])

yy = ((NW_3yr_df['YEAR'] >= 2016))
NW_3yr_df['RATE'][yy] = 0

print(NW_3yr_df['RATE'].describe())

plt.plot(NW_3yr_df['RATE'])

NW_3yr_df['SRC'] = ['NW_'+ str(col) for col in NW_3yr_df['SRC'] ]

print(NW_3yr_df)
# Out:
# count    350592.000000
# mean          0.084472
# std           0.408184
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           2.571000
# Name: RATE, dtype: float64
# count    350592.000000
# mean          0.050683
# std           0.318875
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           2.571000
# Name: RATE, dtype: float64
# c:\users\rapp\appdata\local\programs\python\python36-32\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
#         SO      PATH  YEAR  MM  DD  HH       SRC  RATE  TEMP  VEL
# 0       SO  HOUREMIS  2013  01  01  01  NW_FRAC1   0.0   0.0  0.0
# 1       SO  HOUREMIS  2013  01  01  01  NW_FRAC2   0.0   0.0  0.0
# 2       SO  HOUREMIS  2013  01  01  01  NW_FRAC3   0.0   0.0  0.0
# 3       SO  HOUREMIS  2013  01  01  01  NW_FRAC4   0.0   0.0  0.0
# 4       SO  HOUREMIS  2013  01  01  01  NW_FRAC5   0.0   0.0  0.0
# 5       SO  HOUREMIS  2013  01  01  01  NW_FRAC6   0.0   0.0  0.0
# 6       SO  HOUREMIS  2013  01  01  01  NW_FRAC7   0.0   0.0  0.0
# 7       SO  HOUREMIS  2013  01  01  01  NW_FRAC8   0.0   0.0  0.0
# 8       SO  HOUREMIS  2013  01  01  02  NW_FRAC1   0.0   0.0  0.0
# 9       SO  HOUREMIS  2013  01  01  02  NW_FRAC2   0.0   0.0  0.0
# 10      SO  HOUREMIS  2013  01  01  02  NW_FRAC3   0.0   0.0  0.0
# 11      SO  HOUREMIS  2013  01  01  02  NW_FRAC4   0.0   0.0  0.0
# 12      SO  HOUREMIS  2013  01  01  02  NW_FRAC5   0.0   0.0  0.0
# 13      SO  HOUREMIS  2013  01  01  02  NW_FRAC6   0.0   0.0  0.0
# 14      SO  HOUREMIS  2013  01  01  02  NW_FRAC7   0.0   0.0  0.0
# 15      SO  HOUREMIS  2013  01  01  02  NW_FRAC8   0.0   0.0  0.0
# 16      SO  HOUREMIS  2013  01  01  03  NW_FRAC1   0.0   0.0  0.0
# 17      SO  HOUREMIS  2013  01  01  03  NW_FRAC2   0.0   0.0  0.0
# 18      SO  HOUREMIS  2013  01  01  03  NW_FRAC3   0.0   0.0  0.0
# 19      SO  HOUREMIS  2013  01  01  03  NW_FRAC4   0.0   0.0  0.0
# 20      SO  HOUREMIS  2013  01  01  03  NW_FRAC5   0.0   0.0  0.0
# 21      SO  HOUREMIS  2013  01  01  03  NW_FRAC6   0.0   0.0  0.0
# 22      SO  HOUREMIS  2013  01  01  03  NW_FRAC7   0.0   0.0  0.0
# 23      SO  HOUREMIS  2013  01  01  03  NW_FRAC8   0.0   0.0  0.0
# 24      SO  HOUREMIS  2013  01  01  04  NW_FRAC1   0.0   0.0  0.0
# 25      SO  HOUREMIS  2013  01  01  04  NW_FRAC2   0.0   0.0  0.0
# 26      SO  HOUREMIS  2013  01  01  04  NW_FRAC3   0.0   0.0  0.0
# 27      SO  HOUREMIS  2013  01  01  04  NW_FRAC4   0.0   0.0  0.0
# 28      SO  HOUREMIS  2013  01  01  04  NW_FRAC5   0.0   0.0  0.0
# 29      SO  HOUREMIS  2013  01  01  04  NW_FRAC6   0.0   0.0  0.0
# ...     ..       ...   ...  ..  ..  ..       ...   ...   ...  ...
# 350562  SO  HOUREMIS  2017  12  31  21  NW_FRAC3   0.0   0.0  0.0
# 350563  SO  HOUREMIS  2017  12  31  21  NW_FRAC4   0.0   0.0  0.0
# 350564  SO  HOUREMIS  2017  12  31  21  NW_FRAC5   0.0   0.0  0.0
# 350565  SO  HOUREMIS  2017  12  31  21  NW_FRAC6   0.0   0.0  0.0
# 350566  SO  HOUREMIS  2017  12  31  21  NW_FRAC7   0.0   0.0  0.0
# 350567  SO  HOUREMIS  2017  12  31  21  NW_FRAC8   0.0   0.0  0.0
# 350568  SO  HOUREMIS  2017  12  31  22  NW_FRAC1   0.0   0.0  0.0
# 350569  SO  HOUREMIS  2017  12  31  22  NW_FRAC2   0.0   0.0  0.0
# 350570  SO  HOUREMIS  2017  12  31  22  NW_FRAC3   0.0   0.0  0.0
# 350571  SO  HOUREMIS  2017  12  31  22  NW_FRAC4   0.0   0.0  0.0
# 350572  SO  HOUREMIS  2017  12  31  22  NW_FRAC5   0.0   0.0  0.0
# 350573  SO  HOUREMIS  2017  12  31  22  NW_FRAC6   0.0   0.0  0.0
# 350574  SO  HOUREMIS  2017  12  31  22  NW_FRAC7   0.0   0.0  0.0
# 350575  SO  HOUREMIS  2017  12  31  22  NW_FRAC8   0.0   0.0  0.0
# 350576  SO  HOUREMIS  2017  12  31  23  NW_FRAC1   0.0   0.0  0.0
# 350577  SO  HOUREMIS  2017  12  31  23  NW_FRAC2   0.0   0.0  0.0
# 350578  SO  HOUREMIS  2017  12  31  23  NW_FRAC3   0.0   0.0  0.0
# 350579  SO  HOUREMIS  2017  12  31  23  NW_FRAC4   0.0   0.0  0.0
# 350580  SO  HOUREMIS  2017  12  31  23  NW_FRAC5   0.0   0.0  0.0
# 350581  SO  HOUREMIS  2017  12  31  23  NW_FRAC6   0.0   0.0  0.0
# 350582  SO  HOUREMIS  2017  12  31  23  NW_FRAC7   0.0   0.0  0.0
# 350583  SO  HOUREMIS  2017  12  31  23  NW_FRAC8   0.0   0.0  0.0
# 350584  SO  HOUREMIS  2017  12  31  24  NW_FRAC1   0.0   0.0  0.0
# 350585  SO  HOUREMIS  2017  12  31  24  NW_FRAC2   0.0   0.0  0.0
# 350586  SO  HOUREMIS  2017  12  31  24  NW_FRAC3   0.0   0.0  0.0
# 350587  SO  HOUREMIS  2017  12  31  24  NW_FRAC4   0.0   0.0  0.0
# 350588  SO  HOUREMIS  2017  12  31  24  NW_FRAC5   0.0   0.0  0.0
# 350589  SO  HOUREMIS  2017  12  31  24  NW_FRAC6   0.0   0.0  0.0
# 350590  SO  HOUREMIS  2017  12  31  24  NW_FRAC7   0.0   0.0  0.0
# 350591  SO  HOUREMIS  2017  12  31  24  NW_FRAC8   0.0   0.0  0.0
#
# [350592 rows x 10 columns]

# %%
import sys
#NE_df['YYMMDDHH'] = NE_df['YEAR'].map(str) + NE_df['MM'].map(str) + NE_df['DD'].map(str) + NE_df['HH'].map(str)
NW_3yr_df['YYYYMMDDHH'] = NW_3yr_df['YEAR'].map(str) + NW_3yr_df['MM'].map(str) + NW_3yr_df['DD'].map(str) + NW_3yr_df['HH'].map(str)
NE_2yr_df['YYYYMMDDHH'] = NE_2yr_df['YEAR'].map(str) + NE_2yr_df['MM'].map(str) + NE_2yr_df['DD'].map(str) + NE_2yr_df['HH'].map(str)

print(NE_2yr_df.keys())

#print(NE_df['YYMMDDHH'])
NE2yr_NW3yr_df = pd.concat([NE_2yr_df, NW_3yr_df]).sort_values(by=['YYYYMMDDHH', 'SRC'])
print(NE2yr_NW3yr_df)
#

NE2yr_NW3yr_df.drop('YYYYMMDDHH', axis = 1, inplace = True)

print(NE2yr_NW3yr_df)
# Out:
# Index(['SO', 'PATH', 'YEAR', 'MM', 'DD', 'HH', 'SRC', 'RATE', 'TEMP', 'VEL',
#        'YYYYMMDDHH'],
#       dtype='object')
#         SO      PATH  YEAR  MM  DD  HH       SRC  RATE  TEMP  VEL  YYYYMMDDHH
# 0       SO  HOUREMIS  2013  01  01  01  NE_FRAC1   0.0   0.0  0.0  2013010101
# 1       SO  HOUREMIS  2013  01  01  01  NE_FRAC2   0.0   0.0  0.0  2013010101
# 2       SO  HOUREMIS  2013  01  01  01  NE_FRAC3   0.0   0.0  0.0  2013010101
# 3       SO  HOUREMIS  2013  01  01  01  NE_FRAC4   0.0   0.0  0.0  2013010101
# 4       SO  HOUREMIS  2013  01  01  01  NE_FRAC5   0.0   0.0  0.0  2013010101
# 5       SO  HOUREMIS  2013  01  01  01  NE_FRAC6   0.0   0.0  0.0  2013010101
# 6       SO  HOUREMIS  2013  01  01  01  NE_FRAC7   0.0   0.0  0.0  2013010101
# 7       SO  HOUREMIS  2013  01  01  01  NE_FRAC8   0.0   0.0  0.0  2013010101
# 0       SO  HOUREMIS  2013  01  01  01  NW_FRAC1   0.0   0.0  0.0  2013010101
# 1       SO  HOUREMIS  2013  01  01  01  NW_FRAC2   0.0   0.0  0.0  2013010101
# 2       SO  HOUREMIS  2013  01  01  01  NW_FRAC3   0.0   0.0  0.0  2013010101
# 3       SO  HOUREMIS  2013  01  01  01  NW_FRAC4   0.0   0.0  0.0  2013010101
# 4       SO  HOUREMIS  2013  01  01  01  NW_FRAC5   0.0   0.0  0.0  2013010101
# 5       SO  HOUREMIS  2013  01  01  01  NW_FRAC6   0.0   0.0  0.0  2013010101
# 6       SO  HOUREMIS  2013  01  01  01  NW_FRAC7   0.0   0.0  0.0  2013010101
# 7       SO  HOUREMIS  2013  01  01  01  NW_FRAC8   0.0   0.0  0.0  2013010101
# 8       SO  HOUREMIS  2013  01  01  02  NE_FRAC1   0.0   0.0  0.0  2013010102
# 9       SO  HOUREMIS  2013  01  01  02  NE_FRAC2   0.0   0.0  0.0  2013010102
# 10      SO  HOUREMIS  2013  01  01  02  NE_FRAC3   0.0   0.0  0.0  2013010102
# 11      SO  HOUREMIS  2013  01  01  02  NE_FRAC4   0.0   0.0  0.0  2013010102
# 12      SO  HOUREMIS  2013  01  01  02  NE_FRAC5   0.0   0.0  0.0  2013010102
# 13      SO  HOUREMIS  2013  01  01  02  NE_FRAC6   0.0   0.0  0.0  2013010102
# 14      SO  HOUREMIS  2013  01  01  02  NE_FRAC7   0.0   0.0  0.0  2013010102
# 15      SO  HOUREMIS  2013  01  01  02  NE_FRAC8   0.0   0.0  0.0  2013010102
# 8       SO  HOUREMIS  2013  01  01  02  NW_FRAC1   0.0   0.0  0.0  2013010102
# 9       SO  HOUREMIS  2013  01  01  02  NW_FRAC2   0.0   0.0  0.0  2013010102
# 10      SO  HOUREMIS  2013  01  01  02  NW_FRAC3   0.0   0.0  0.0  2013010102
# 11      SO  HOUREMIS  2013  01  01  02  NW_FRAC4   0.0   0.0  0.0  2013010102
# 12      SO  HOUREMIS  2013  01  01  02  NW_FRAC5   0.0   0.0  0.0  2013010102
# 13      SO  HOUREMIS  2013  01  01  02  NW_FRAC6   0.0   0.0  0.0  2013010102
# ...     ..       ...   ...  ..  ..  ..       ...   ...   ...  ...         ...
# 350578  SO  HOUREMIS  2017  12  31  23  NE_FRAC3   0.0   0.0  0.0  2017123123
# 350579  SO  HOUREMIS  2017  12  31  23  NE_FRAC4   0.0   0.0  0.0  2017123123
# 350580  SO  HOUREMIS  2017  12  31  23  NE_FRAC5   0.0   0.0  0.0  2017123123
# 350581  SO  HOUREMIS  2017  12  31  23  NE_FRAC6   0.0   0.0  0.0  2017123123
# 350582  SO  HOUREMIS  2017  12  31  23  NE_FRAC7   0.0   0.0  0.0  2017123123
# 350583  SO  HOUREMIS  2017  12  31  23  NE_FRAC8   0.0   0.0  0.0  2017123123
# 350576  SO  HOUREMIS  2017  12  31  23  NW_FRAC1   0.0   0.0  0.0  2017123123
# 350577  SO  HOUREMIS  2017  12  31  23  NW_FRAC2   0.0   0.0  0.0  2017123123
# 350578  SO  HOUREMIS  2017  12  31  23  NW_FRAC3   0.0   0.0  0.0  2017123123
# 350579  SO  HOUREMIS  2017  12  31  23  NW_FRAC4   0.0   0.0  0.0  2017123123
# 350580  SO  HOUREMIS  2017  12  31  23  NW_FRAC5   0.0   0.0  0.0  2017123123
# 350581  SO  HOUREMIS  2017  12  31  23  NW_FRAC6   0.0   0.0  0.0  2017123123
# 350582  SO  HOUREMIS  2017  12  31  23  NW_FRAC7   0.0   0.0  0.0  2017123123
# 350583  SO  HOUREMIS  2017  12  31  23  NW_FRAC8   0.0   0.0  0.0  2017123123
# 350584  SO  HOUREMIS  2017  12  31  24  NE_FRAC1   0.0   0.0  0.0  2017123124
# 350585  SO  HOUREMIS  2017  12  31  24  NE_FRAC2   0.0   0.0  0.0  2017123124
# 350586  SO  HOUREMIS  2017  12  31  24  NE_FRAC3   0.0   0.0  0.0  2017123124
# 350587  SO  HOUREMIS  2017  12  31  24  NE_FRAC4   0.0   0.0  0.0  2017123124
# 350588  SO  HOUREMIS  2017  12  31  24  NE_FRAC5   0.0   0.0  0.0  2017123124
# 350589  SO  HOUREMIS  2017  12  31  24  NE_FRAC6   0.0   0.0  0.0  2017123124
# 350590  SO  HOUREMIS  2017  12  31  24  NE_FRAC7   0.0   0.0  0.0  2017123124
# 350591  SO  HOUREMIS  2017  12  31  24  NE_FRAC8   0.0   0.0  0.0  2017123124
# 350584  SO  HOUREMIS  2017  12  31  24  NW_FRAC1   0.0   0.0  0.0  2017123124
# 350585  SO  HOUREMIS  2017  12  31  24  NW_FRAC2   0.0   0.0  0.0  2017123124
# 350586  SO  HOUREMIS  2017  12  31  24  NW_FRAC3   0.0   0.0  0.0  2017123124
# 350587  SO  HOUREMIS  2017  12  31  24  NW_FRAC4   0.0   0.0  0.0  2017123124
# 350588  SO  HOUREMIS  2017  12  31  24  NW_FRAC5   0.0   0.0  0.0  2017123124
# 350589  SO  HOUREMIS  2017  12  31  24  NW_FRAC6   0.0   0.0  0.0  2017123124
# 350590  SO  HOUREMIS  2017  12  31  24  NW_FRAC7   0.0   0.0  0.0  2017123124
# 350591  SO  HOUREMIS  2017  12  31  24  NW_FRAC8   0.0   0.0  0.0  2017123124
#
# [701184 rows x 11 columns]
#         SO      PATH  YEAR  MM  DD  HH       SRC  RATE  TEMP  VEL
# 0       SO  HOUREMIS  2013  01  01  01  NE_FRAC1   0.0   0.0  0.0
# 1       SO  HOUREMIS  2013  01  01  01  NE_FRAC2   0.0   0.0  0.0
# 2       SO  HOUREMIS  2013  01  01  01  NE_FRAC3   0.0   0.0  0.0
# 3       SO  HOUREMIS  2013  01  01  01  NE_FRAC4   0.0   0.0  0.0
# 4       SO  HOUREMIS  2013  01  01  01  NE_FRAC5   0.0   0.0  0.0
# 5       SO  HOUREMIS  2013  01  01  01  NE_FRAC6   0.0   0.0  0.0
# 6       SO  HOUREMIS  2013  01  01  01  NE_FRAC7   0.0   0.0  0.0
# 7       SO  HOUREMIS  2013  01  01  01  NE_FRAC8   0.0   0.0  0.0
# 0       SO  HOUREMIS  2013  01  01  01  NW_FRAC1   0.0   0.0  0.0
# 1       SO  HOUREMIS  2013  01  01  01  NW_FRAC2   0.0   0.0  0.0
# 2       SO  HOUREMIS  2013  01  01  01  NW_FRAC3   0.0   0.0  0.0
# 3       SO  HOUREMIS  2013  01  01  01  NW_FRAC4   0.0   0.0  0.0
# 4       SO  HOUREMIS  2013  01  01  01  NW_FRAC5   0.0   0.0  0.0
# 5       SO  HOUREMIS  2013  01  01  01  NW_FRAC6   0.0   0.0  0.0
# 6       SO  HOUREMIS  2013  01  01  01  NW_FRAC7   0.0   0.0  0.0
# 7       SO  HOUREMIS  2013  01  01  01  NW_FRAC8   0.0   0.0  0.0
# 8       SO  HOUREMIS  2013  01  01  02  NE_FRAC1   0.0   0.0  0.0
# 9       SO  HOUREMIS  2013  01  01  02  NE_FRAC2   0.0   0.0  0.0
# 10      SO  HOUREMIS  2013  01  01  02  NE_FRAC3   0.0   0.0  0.0
# 11      SO  HOUREMIS  2013  01  01  02  NE_FRAC4   0.0   0.0  0.0
# 12      SO  HOUREMIS  2013  01  01  02  NE_FRAC5   0.0   0.0  0.0
# 13      SO  HOUREMIS  2013  01  01  02  NE_FRAC6   0.0   0.0  0.0
# 14      SO  HOUREMIS  2013  01  01  02  NE_FRAC7   0.0   0.0  0.0
# 15      SO  HOUREMIS  2013  01  01  02  NE_FRAC8   0.0   0.0  0.0
# 8       SO  HOUREMIS  2013  01  01  02  NW_FRAC1   0.0   0.0  0.0
# 9       SO  HOUREMIS  2013  01  01  02  NW_FRAC2   0.0   0.0  0.0
# 10      SO  HOUREMIS  2013  01  01  02  NW_FRAC3   0.0   0.0  0.0
# 11      SO  HOUREMIS  2013  01  01  02  NW_FRAC4   0.0   0.0  0.0
# 12      SO  HOUREMIS  2013  01  01  02  NW_FRAC5   0.0   0.0  0.0
# 13      SO  HOUREMIS  2013  01  01  02  NW_FRAC6   0.0   0.0  0.0
# ...     ..       ...   ...  ..  ..  ..       ...   ...   ...  ...
# 350578  SO  HOUREMIS  2017  12  31  23  NE_FRAC3   0.0   0.0  0.0
# 350579  SO  HOUREMIS  2017  12  31  23  NE_FRAC4   0.0   0.0  0.0
# 350580  SO  HOUREMIS  2017  12  31  23  NE_FRAC5   0.0   0.0  0.0
# 350581  SO  HOUREMIS  2017  12  31  23  NE_FRAC6   0.0   0.0  0.0
# 350582  SO  HOUREMIS  2017  12  31  23  NE_FRAC7   0.0   0.0  0.0
# 350583  SO  HOUREMIS  2017  12  31  23  NE_FRAC8   0.0   0.0  0.0
# 350576  SO  HOUREMIS  2017  12  31  23  NW_FRAC1   0.0   0.0  0.0
# 350577  SO  HOUREMIS  2017  12  31  23  NW_FRAC2   0.0   0.0  0.0
# 350578  SO  HOUREMIS  2017  12  31  23  NW_FRAC3   0.0   0.0  0.0
# 350579  SO  HOUREMIS  2017  12  31  23  NW_FRAC4   0.0   0.0  0.0
# 350580  SO  HOUREMIS  2017  12  31  23  NW_FRAC5   0.0   0.0  0.0
# 350581  SO  HOUREMIS  2017  12  31  23  NW_FRAC6   0.0   0.0  0.0
# 350582  SO  HOUREMIS  2017  12  31  23  NW_FRAC7   0.0   0.0  0.0
# 350583  SO  HOUREMIS  2017  12  31  23  NW_FRAC8   0.0   0.0  0.0
# 350584  SO  HOUREMIS  2017  12  31  24  NE_FRAC1   0.0   0.0  0.0
# 350585  SO  HOUREMIS  2017  12  31  24  NE_FRAC2   0.0   0.0  0.0
# 350586  SO  HOUREMIS  2017  12  31  24  NE_FRAC3   0.0   0.0  0.0
# 350587  SO  HOUREMIS  2017  12  31  24  NE_FRAC4   0.0   0.0  0.0
# 350588  SO  HOUREMIS  2017  12  31  24  NE_FRAC5   0.0   0.0  0.0
# 350589  SO  HOUREMIS  2017  12  31  24  NE_FRAC6   0.0   0.0  0.0
# 350590  SO  HOUREMIS  2017  12  31  24  NE_FRAC7   0.0   0.0  0.0
# 350591  SO  HOUREMIS  2017  12  31  24  NE_FRAC8   0.0   0.0  0.0
# 350584  SO  HOUREMIS  2017  12  31  24  NW_FRAC1   0.0   0.0  0.0
# 350585  SO  HOUREMIS  2017  12  31  24  NW_FRAC2   0.0   0.0  0.0
# 350586  SO  HOUREMIS  2017  12  31  24  NW_FRAC3   0.0   0.0  0.0
# 350587  SO  HOUREMIS  2017  12  31  24  NW_FRAC4   0.0   0.0  0.0
# 350588  SO  HOUREMIS  2017  12  31  24  NW_FRAC5   0.0   0.0  0.0
# 350589  SO  HOUREMIS  2017  12  31  24  NW_FRAC6   0.0   0.0  0.0
# 350590  SO  HOUREMIS  2017  12  31  24  NW_FRAC7   0.0   0.0  0.0
# 350591  SO  HOUREMIS  2017  12  31  24  NW_FRAC8   0.0   0.0  0.0
#
# [701184 rows x 10 columns]

# %%
NE2yr_NW3yr_df.to_csv('C:/Users/RAPP/Documents/Capstone/NENW_HOUREMIS3_2-8-2019.dat',sep = ' ', header = False, index = False)
